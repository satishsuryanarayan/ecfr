# %% [markdown]
# # Script to interact with CFR Insights API web site and plot KPIs

# %%
import json
import requests
from requests.adapters import HTTPAdapter
from urllib3.util.retry import Retry

# %%
retry_strategy = Retry(
    total=10,
    backoff_factor=1
)
adapter = HTTPAdapter(max_retries=retry_strategy)

# %% [markdown]
# # Initialize the database

# %%
with requests.session() as session:
    session.mount("http://", adapter)
    session.headers.update({"Content-Type": "application/json", "Accept": "application/json"})
    json_data = json.dumps({"force": False})
    response = session.post("http://127.0.0.1:8000/init-db", data=json_data)
    print(response.status_code)
# Out:
# 201

# %% [markdown]
# # Populate titles and amendments from source (eCFR API)

# %%
with requests.session() as session:
    session.mount("http://", adapter)
    session.headers.update({"Content-Type": "application/json", "Accept": "application/json"})
    response = session.post("http://127.0.0.1:8000/titles")
    print(response.status_code)
# Out:
# 201

# %% [markdown]
# # Populate agencies and CFR references from source (eCFR API)

# %%
with requests.session() as session:
    session.mount("http://", adapter)
    session.headers.update({"Content-Type": "application/json", "Accept": "application/json"})
    response = session.post("http://127.0.0.1:8000/agencies")
    print(response.status_code)
# Out:
# 201

# %% [markdown]
# # Get the list of titles and amendments

# %%
with requests.session() as session:
    session.mount("http://", adapter)
    session.headers.update({"Content-Type": "application/json", "Accept": "application/json"})
    response = session.get("http://127.0.0.1:8000/titles")
    print(response.status_code)
    print(json.dumps(response.json(), indent=4))
# Out:
# IOPub data rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_data_rate_limit`.
#
# Current values:
# ServerApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# ServerApp.rate_limit_window=3.0 (secs)

# %% [markdown]
# # Get the list of agencies and CFR references

# %%
with requests.session() as session:
    session.mount("http://", adapter)
    session.headers.update({"Content-Type": "application/json", "Accept": "application/json"})
    response = session.get("http://127.0.0.1:8000/agencies")
    print(response.status_code)
    print(json.dumps(response.json(), indent=4))
# Out:
# 200
# [
#     {
#         "id": 1,
#         "short_name": "ACUS",
#         "name": "Administrative Conference of the United States",
#         "parent_id": null,
#         "cfr_references": [
#             {
#                 "id": 1,
#                 "agency_id": 1,
#                 "parent_agency_id": null,
#                 "reference": {
#                     "title": 1,
#                     "chapter": "III"
#                 }
#             }
#         ]
#     },
#     {
#         "id": 2,
#         "short_name": "ACHP",
#         "name": "Advisory Council on Historic Preservation",
#         "parent_id": null,
#         "cfr_references": [
#             {
#                 "id": 2,
#                 "agency_id": 2,
#                 "parent_agency_id": null,
#                 "reference": {
#                     "title": 36,
#                     "chapter": "VIII"
#                 }
#             }
#         ]
#     },
#     {
#         "id": 3,
#         "short_name": "SIGAR",
#         "name": "Special Inspector General for Afghanistan Reconstruction",
#         "parent_id": null,
#         "cfr_references": [
#             {
#                 "id": 3,
#                 "agency_id": 3,
#                 "parent_agency_id": null,
#                 "reference": {
#                     "title": 5,
#                     "chapter": "LXXXIII"
#                 }
#             }
#         ]
#     },
#     {
#         "id": 4,
#         "short_name": "USADF",
#         "name": "African Development Foundation",
#         "parent_id": null,
#         "cfr_references": [
#             {
#                 "id": 4,
#                 "agency_id": 4,
#                 "parent_agency_id": null,
#                 "reference": {
#                     "title": 22,
#                     "chapter": "XV"
#                 }
#             },
#             {
#                 "id": 5,
#                 "agency_id": 4,
#                 "parent_agency_id": null,
#                 "reference": {
#                     "title": 48,
#                     "chapter": "57"
#                 }
#             }
#         ]
#     },
#     {
#         "id": 5,
#         "short_name": "USAGM",
#         "name": "United States Agency for Global Media",
#         "parent_id": null,
#         "cfr_references": [
#             {
#                 "id": 6,
#                 "agency_id": 5,
#                 "parent_agency_id": null,
#                 "reference": {
#                     "title": 22,
#                     "chapter": "V"
#                 }
#             },
#             {
#                 "id": 7,
#                 "agency_id": 5,
#                 "parent_agency_id": null,
#                 "reference": {
#                     "title": 48,
#                     "chapter": "19"
#                 }
#             }
#         ]
#     },
#     {
#         "id": 6,
#         "short_name": "USDA",
#         "name": "Department of Agriculture",
#         "parent_id": null,
#         "cfr_references": [
#             {
#                 "id": 8,
#                 "agency_id": 6,
#                 "parent_agency_id": null,
#                 "reference": {
#                     "title": 2,
#                     "chapter": "IV"
#                 }
#             },
#             {
#                 "id": 9,
#                 "agency_id": 6,
#                 "parent_agency_id": null,
#                 "reference": {
#                     "title": 5,
#                     "chapter": "LXXIII"
#                 }
#             },
#             {
#                 "id": 10,
#                 "agency_id": 6,
#                 "parent_agency_id": null,
#                 "reference": {
#                     "title": 7,
#                     "chapter": "XVI"
#                 }
#             },
#             {
#                 "id": 11,
#                 "agency_id": 6,
#                 "parent_agency_id": null,
#                 "reference": {
#                     "title": 7,
#                     "chapter": "XX"
#                 }
#             },
#             {
#                 "id": 12,
#                 "agency_id": 6,
#                 "parent_agency_id": null,
#                 "reference": {
#                     "title": 48,
#                     "chapter": "4"
#                 }
#             }
#         ]
#     },
#     {
#         "id": 7,
#         "short_name": "AMS",
#         "name": "Agricultural Marketing Service, Department of Agriculture",
#         "parent_id": 6,
#         "cfr_references": [
#             {
#                 "id": 13,
#                 "agency_id": 7,
#                 "parent_agency_id": 6,
#                 "reference": {
#                     "title": 7,
#                     "chapter": "I"
#                 }
#             },
#             {
#                 "id": 14,
#                 "agency_id": 7,
#                 "parent_agency_id": 6,
#                 "reference": {
#                     "title": 7,
#                     "chapter": "VIII"
#                 }
#             },
#             {
#                 "id": 15,
#                 "agency_id": 7,
#                 "parent_agency_id": 6,
#                 "reference": {
#                     "title": 7,
#                     "chapter": "IX"
#                 }
#             },
#             {
#                 "id": 16,
#                 "agency_id": 7,
#                 "parent_agency_id": 6,
#                 "reference": {
#                     "title": 7,
#                     "chapter": "X"
#                 }
#             },
#             {
#                 "id": 17,
#                 "agency_id": 7,
#                 "parent_agency_id": 6,
#                 "reference": {
#                     "title": 7,
#                     "chapter": "XI"
#                 }
#             },
#             {
#                 "id": 18,
#                 "agency_id": 7,
#                 "parent_agency_id": 6,
#                 "reference": {
#                     "title": 9,
#                     "chapter": "II"
#                 }
#             }
#         ]
#     },
#     {
#         "id": 8,
#         "short_name": "ARS",
#         "name": "Agricultural Research Service, Department of Agriculture",
#         "parent_id": 6,
#         "cfr_references": [
#             {
#                 "id": 19,
#                 "agency_id": 8,
#                 "parent_agency_id": 6,
#                 "reference": {
#                     "title": 7,
#                     "chapter": "V"
#                 }
#             }
#         ]
#     },
#     {
#         "id": 9,
#         "short_name": "APHIS",
#         "name": "Animal and Plant Health Inspection Service, Department of Agriculture",
#         "parent_id": 6,
#         "cfr_references": [
#             {
#                 "id": 20,
#                 "agency_id": 9,
#                 "parent_agency_id": 6,
#                 "reference": {
#                     "title": 7,
#                     "chapter": "III"
#                 }
#             },
#             {
#                 "id": 21,
#                 "agency_id": 9,
#                 "parent_agency_id": 6,
#                 "reference": {
#                     "title": 9,
#                     "chapter": "I"
#                 }
#             }
#         ]
#     },
#     {
#         "id": 10,
#         "short_name": "CCC",
#         "name": "Commodity Credit Corporation, Department of Agriculture",
#         "parent_id": 6,
#         "cfr_references": [
#             {
#                 "id": 22,
#                 "agency_id": 10,
#                 "parent_agency_id": 6,
#                 "reference": {
#                     "title": 7,
#                     "chapter": "XIV"
#                 }
#             }
#         ]
#     },
#     {
#         "id": 11,
#         "short_name": "ERS",
#         "name": "Economic Research Service, Department of Agriculture",
#         "parent_id": 6,
#         "cfr_references": [
#             {
#                 "id": 23,
#                 "agency_id": 11,
#                 "parent_agency_id": 6,
#                 "reference": {
#                     "title": 7,
#                     "chapter": "XXXVII"
#                 }
#             }
#         ]
#     },
#     {
#         "id": 12,
#         "short_name": "FSA",
#         "name": "Farm Service Agency, Department of Agriculture",
#         "parent_id": 6,
#         "cfr_references": [
#             {
#                 "id": 24,
#                 "agency_id": 12,
#                 "parent_agency_id": 6,
#                 "reference": {
#                     "title": 7,
#                     "chapter": "VII"
#                 }
#             }
#         ]
#     },
#     {
#         "id": 13,
#         "short_name": "FCIC",
#         "name": "Federal Crop Insurance Corporation, Department of Agriculture",
#         "parent_id": 6,
#         "cfr_references": [
#             {
#                 "id": 25,
#                 "agency_id": 13,
#                 "parent_agency_id": 6,
#                 "reference": {
#                     "title": 7,
#                     "chapter": "IV"
#                 }
#             }
#         ]
#     },
#     {
#         "id": 14,
#         "short_name": "FNS",
#         "name": "Food and Nutrition Service, Department of Agriculture",
#         "parent_id": 6,
#         "cfr_references": [
#             {
#                 "id": 26,
#                 "agency_id": 14,
#                 "parent_agency_id": 6,
#                 "reference": {
#                     "title": 7,
#                     "chapter": "II"
#                 }
#             }
#         ]
#     },
#     {
#         "id": 15,
#         "short_name": "FSIS",
#         "name": "Food Safety and Inspection Service, Department of Agriculture",
#         "parent_id": 6,
#         "cfr_references": [
#             {
#                 "id": 27,
#                 "agency_id": 15,
#                 "parent_agency_id": 6,
#                 "reference": {
#                     "title": 9,
#                     "chapter": "III"
#                 }
#             }
#         ]
#     },
#     {
#         "id": 16,
#         "short_name": "FAS",
#         "name": "Foreign Agricultural Service, Department of Agriculture",
#         "parent_id": 6,
#         "cfr_references": [
#             {
#                 "id": 28,
#                 "agency_id": 16,
#                 "parent_agency_id": 6,
#                 "reference": {
#                     "title": 7,
#                     "chapter": "XV"
#                 }
#             }
#         ]
#     },
#     {
#         "id": 17,
#         "short_name": "FS",
#         "name": "Forest Service, Department of Agriculture",
#         "parent_id": 6,
#         "cfr_references": [
#             {
#                 "id": 29,
#                 "agency_id": 17,
#                 "parent_agency_id": 6,
#                 "reference": {
#                     "title": 36,
#                     "chapter": "II"
#                 }
#             }
#         ]
#     },
#     {
#         "id": 18,
#         "short_name": "NASS",
#         "name": "National Agricultural Statistics Service, Department of Agriculture",
#         "parent_id": 6,
#         "cfr_references": [
#             {
#                 "id": 30,
#                 "agency_id": 18,
#                 "parent_agency_id": 6,
#                 "reference": {
#                     "title": 7,
#                     "chapter": "XXXVI"
#                 }
#             }
#         ]
#     },
#     {
#         "id": 19,
#         "short_name": "NIFA",
#         "name": "National Institute of Food and Agriculture, Department of Agriculture",
#         "parent_id": 6,
#         "cfr_references": [
#             {
#                 "id": 31,
#                 "agency_id": 19,
#                 "parent_agency_id": 6,
#                 "reference": {
#                     "title": 7,
#                     "chapter": "XXXIV"
#                 }
#             }
#         ]
#     },
#     {
#         "id": 20,
#         "short_name": "NRCS",
#         "name": "Natural Resources Conservation Service, Department of Agriculture",
#         "parent_id": 6,
#         "cfr_references": [
#             {
#                 "id": 32,
#                 "agency_id": 20,
#                 "parent_agency_id": 6,
#                 "reference": {
#                     "title": 7,
#                     "chapter": "VI"
#                 }
#             }
#         ]
#     },
#     {
#         "id": 21,
#         "short_name": "OAO",
#         "name": "Office of Advocacy and Outreach, Department of Agriculture",
#         "parent_id": 6,
#         "cfr_references": [
#             {
#                 "id": 33,
#                 "agency_id": 21,
#                 "parent_agency_id": 6,
#                 "reference": {
#                     "title": 7,
#                     "chapter": "XXV"
#                 }
#             }
#         ]
#     },
#     {
#         "id": 22,
#         "short_name": null,
#         "name": "Office of Chief Financial Officer, Department of Agriculture",
#         "parent_id": 6,
#         "cfr_references": [
#             {
#                 "id": 34,
#                 "agency_id": 22,
#                 "parent_agency_id": 6,
#                 "reference": {
#                     "title": 7,
#                     "chapter": "XXX"
#                 }
#             }
#         ]
#     },
#     {
#         "id": 23,
#         "short_name": "OEPNU",
#         "name": "Office of Energy Policy and New Uses, Department of Agriculture",
#         "parent_id": 6,
#         "cfr_references": [
#             {
#                 "id": 35,
#                 "agency_id": 23,
#                 "parent_agency_id": 6,
#                 "reference": {
#                     "title": 7,
#                     "chapter": "XXIX"
#                 }
#             }
#         ]
#     },
#     {
#         "id": 24,
#         "short_name": "",
#         "name": "Office of Environmental Quality, Department of Agriculture",
#         "parent_id": 6,
#         "cfr_references": [
#             {
#                 "id": 36,
#                 "agency_id": 24,
#                 "parent_agency_id": 6,
#                 "reference": {
#                     "title": 7,
#                     "chapter": "XXXI"
#                 }
#             }
#         ]
#     },
#     {
#         "id": 25,
#         "short_name": "",
#         "name": "Office of Information Resources Management, Department of Agriculture",
#         "parent_id": 6,
#         "cfr_references": [
#             {
#                 "id": 37,
#                 "agency_id": 25,
#                 "parent_agency_id": 6,
#                 "reference": {
#                     "title": 7,
#                     "chapter": "XXVII"
#                 }
#             }
#         ]
#     },
#     {
#         "id": 26,
#         "short_name": "OIG USDA",
#         "name": "Office of Inspector General, Department of Agriculture",
#         "parent_id": 6,
#         "cfr_references": [
#             {
#                 "id": 38,
#                 "agency_id": 26,
#                 "parent_agency_id": 6,
#                 "reference": {
#                     "title": 7,
#                     "chapter": "XXVI"
#                 }
#             }
#         ]
#     },
#     {
#         "id": 27,
#         "short_name": "",
#         "name": "Office of Operations, Department of Agriculture",
#         "parent_id": 6,
#         "cfr_references": [
#             {
#                 "id": 39,
#                 "agency_id": 27,
#                 "parent_agency_id": 6,
#                 "reference": {
#                     "title": 7,
#                     "chapter": "XXVIII"
#                 }
#             }
#         ]
#     },
#     {
#         "id": 28,
#         "short_name": "OPPM",
#         "name": "Office of Procurement and Property Management, Department of Agriculture",
#         "parent_id": 6,
#         "cfr_references": [
#             {
#                 "id": 40,
#                 "agency_id": 28,
#                 "parent_agency_id": 6,
#                 "reference": {
#                     "title": 7,
#                     "chapter": "XXXII"
#                 }
#             }
#         ]
#     },
#     {
#         "id": 29,
#         "short_name": "",
#         "name": "Office of Secretary of Agriculture, Department of Agriculture",
#         "parent_id": 6,
#         "cfr_references": [
#             {
#                 "id": 41,
#                 "agency_id": 29,
#                 "parent_agency_id": 6,
#                 "reference": {
#                     "title": 7,
#                     "subtitle": "A"
#                 }
#             }
#         ]
#     },
#     {
#         "id": 30,
#         "short_name": null,
#         "name": "Office of Transportation, Department of Agriculture",
#         "parent_id": 6,
#         "cfr_references": [
#             {
#                 "id": 42,
#                 "agency_id": 30,
#                 "parent_agency_id": 6,
#                 "reference": {
#                     "title": 7,
#                     "chapter": "XXXIII"
#                 }
#             }
#         ]
#     },
#     {
#         "id": 31,
#         "short_name": "RBS",
#         "name": "Rural Business-Cooperative Service, Department of Agriculture",
#         "parent_id": 6,
#         "cfr_references": [
#             {
#                 "id": 43,
#                 "agency_id": 31,
#                 "parent_agency_id": 6,
#                 "reference": {
#                     "title": 7,
#                     "chapter": "XVIII"
#                 }
#             },
#             {
#                 "id": 44,
#                 "agency_id": 31,
#                 "parent_agency_id": 6,
#                 "reference": {
#                     "title": 7,
#                     "chapter": "XLII"
#                 }
#             },
#             {
#                 "id": 45,
#                 "agency_id": 31,
#                 "parent_agency_id": 6,
#                 "reference": {
#                     "title": 7,
#                     "chapter": "L"
#                 }
#             }
#         ]
#     },
#     {
#         "id": 32,
#         "short_name": "RHS",
#         "name": "Rural Housing Service, Department of Agriculture",
#         "parent_id": 6,
#         "cfr_references": [
#             {
#                 "id": 46,
#                 "agency_id": 32,
#                 "parent_agency_id": 6,
#                 "reference": {
#                     "title": 7,
#                     "chapter": "XVIII"
#                 }
#             },
#             {
#                 "id": 47,
#                 "agency_id": 32,
#                 "parent_agency_id": 6,
#                 "reference": {
#                     "title": 7,
#                     "chapter": "XXXV"
#                 }
#             },
#             {
#                 "id": 48,
#                 "agency_id": 32,
#                 "parent_agency_id": 6,
#                 "reference": {
#                     "title": 7,
#                     "chapter": "L"
#                 }
#             }
#         ]
#     },
#     {
#         "id": 33,
#         "short_name": "RUS",
#         "name": "Rural Utilities Service, Department of Agriculture",
#         "parent_id": 6,
#         "cfr_references": [
#             {
#                 "id": 49,
#                 "agency_id": 33,
#                 "parent_agency_id": 6,
#                 "reference": {
#                     "title": 7,
#                     "chapter": "XVII"
#                 }
#             },
#             {
#                 "id": 50,
#                 "agency_id": 33,
#                 "parent_agency_id": 6,
#                 "reference": {
#                     "title": 7,
#                     "chapter": "XVIII"
#                 }
#             },
#             {
#                 "id": 51,
#                 "agency_id": 33,
#                 "parent_agency_id": 6,
#                 "reference": {
#                     "title": 7,
#                     "chapter": "XLII"
#                 }
#             },
#             {
#                 "id": 52,
#                 "agency_id": 33,
#                 "parent_agency_id": 6,
#                 "reference": {
#                     "title": 7,
#                     "chapter": "L"
#                 }
#             }
#         ]
#     },
#     {
#         "id": 34,
#         "short_name": null,
#         "name": "World Agricultural Outlook Board, Department of Agriculture",
#         "parent_id": 6,
#         "cfr_references": [
#             {
#                 "id": 53,
#                 "agency_id": 34,
#                 "parent_agency_id": 6,
#                 "reference": {
#                     "title": 7,
#                     "chapter": "XXXVIII"
#                 }
#             }
#         ]
#     },
#     {
#         "id": 35,
#         "short_name": "ATSB",
#         "name": "Air Transportation System Stabilization",
#         "parent_id": null,
#         "cfr_references": [
#             {
#                 "id": 54,
#                 "agency_id": 35,
#                 "parent_agency_id": null,
#                 "reference": {
#                     "title": 14,
#                     "chapter": "VI"
#                 }
#             }
#         ]
#     },
#     {
#         "id": 36,
#         "short_name": "ABMC",
#         "name": "American Battle Monuments Commission",
#         "parent_id": null,
#         "cfr_references": [
#             {
#                 "id": 55,
#                 "agency_id": 36,
#                 "parent_agency_id": null,
#                 "reference": {
#                     "title": 36,
#                     "chapter": "IV"
#                 }
#             }
#         ]
#     },
#     {
#         "id": 37,
#         "short_name": "ARC",
#         "name": "Appalachian Regional Commission",
#         "parent_id": null,
#         "cfr_references": [
#             {
#                 "id": 56,
#                 "agency_id": 37,
#                 "parent_agency_id": null,
#                 "reference": {
#                     "title": 5,
#                     "chapter": "IX"
#                 }
#             }
#         ]
#     },
#     {
#         "id": 38,
#         "short_name": "ATBCB",
#         "name": "Architectural and Transportation Barriers Compliance Board",
#         "parent_id": null,
#         "cfr_references": [
#             {
#                 "id": 57,
#                 "agency_id": 38,
#                 "parent_agency_id": null,
#                 "reference": {
#                     "title": 36,
#                     "chapter": "XI"
#                 }
#             }
#         ]
#     },
#     {
#         "id": 39,
#         "short_name": "ARCTIC",
#         "name": "Arctic Research Commission",
#         "parent_id": null,
#         "cfr_references": [
#             {
#                 "id": 58,
#                 "agency_id": 39,
#                 "parent_agency_id": null,
#                 "reference": {
#                     "title": 45,
#                     "chapter": "XXIII"
#                 }
#             }
#         ]
#     },
#     {
#         "id": 40,
#         "short_name": "AFRH",
#         "name": "Armed Forces Retirement Home",
#         "parent_id": null,
#         "cfr_references": [
#             {
#                 "id": 59,
#                 "agency_id": 40,
#                 "parent_agency_id": null,
#                 "reference": {
#                     "title": 5,
#                     "chapter": "XI"
#                 }
#             },
#             {
#                 "id": 60,
#                 "agency_id": 40,
#                 "parent_agency_id": null,
#                 "reference": {
#                     "title": 38,
#                     "chapter": "II"
#                 }
#             }
#         ]
#     },
#     {
#         "id": 41,
#         "short_name": "CPPBSD",
#         "name": "Committee for Purchase From People Who Are Blind or Severely Disabled",
#         "parent_id": null,
#         "cfr_references": [
#             {
#                 "id": 61,
#                 "agency_id": 41,
#                 "parent_agency_id": null,
#                 "reference": {
#                     "title": 41,
#                     "chapter": "51"
#                 }
#             }
#         ]
#     },
#     {
#         "id": 42,
#         "short_name": "CIA",
#         "name": "Central Intelligence Agency",
#         "parent_id": null,
#         "cfr_references": [
#             {
#                 "id": 62,
#                 "agency_id": 42,
#                 "parent_agency_id": null,
#                 "reference": {
#                     "title": 32,
#                     "chapter": "XIX"
#                 }
#             }
#         ]
#     },
#     {
#         "id": 43,
#         "short_name": "CSB",
#         "name": "Chemical Safety and Hazard Investigation Board",
#         "parent_id": null,
#         "cfr_references": [
#             {
#                 "id": 63,
#                 "agency_id": 43,
#                 "parent_agency_id": null,
#                 "reference": {
#                     "title": 40,
#                     "chapter": "VI"
#                 }
#             }
#         ]
#     },
#     {
#         "id": 44,
#         "short_name": "CRC",
#         "name": "Commission on Civil Rights",
#         "parent_id": null,
#         "cfr_references": [
#             {
#                 "id": 64,
#                 "agency_id": 44,
#                 "parent_agency_id": null,
#                 "reference": {
#                     "title": 5,
#                     "chapter": "LXVIII"
#                 }
#             },
#             {
#                 "id": 65,
#                 "agency_id": 44,
#                 "parent_agency_id": null,
#                 "reference": {
#                     "title": 45,
#                     "chapter": "VII"
#                 }
#             }
#         ]
#     },
#     {
#         "id": 45,
#         "short_name": "DOC",
#         "name": "Department of Commerce",
#         "parent_id": null,
#         "cfr_references": [
#             {
#                 "id": 66,
#                 "agency_id": 45,
#                 "parent_agency_id": null,
#                 "reference": {
#                     "title": 2,
#                     "chapter": "XIII"
#                 }
#             },
#             {
#                 "id": 67,
#                 "agency_id": 45,
#                 "parent_agency_id": null,
#                 "reference": {
#                     "title": 44,
#                     "chapter": "IV"
#                 }
#             },
#             {
#                 "id": 68,
#                 "agency_id": 45,
#                 "parent_agency_id": null,
#                 "reference": {
#                     "title": 48,
#                     "chapter": "13"
#                 }
#             }
#         ]
#     },
#     {
#         "id": 46,
#         "short_name": "USBC",
#         "name": "Bureau of Census, Department of Commerce",
#         "parent_id": 45,
#         "cfr_references": [
#             {
#                 "id": 69,
#                 "agency_id": 46,
#                 "parent_agency_id": 45,
#                 "reference": {
#                     "title": 15,
#                     "chapter": "I"
#                 }
#             }
#         ]
#     },
#     {
#         "id": 47,
#         "short_name": "EAB",
#         "name": "Bureau of Economic Analysis, Department of Commerce",
#         "parent_id": 45,
#         "cfr_references": [
#             {
#                 "id": 70,
#                 "agency_id": 47,
#                 "parent_agency_id": 45,
#                 "reference": {
#                     "title": 15,
#                     "chapter": "VIII"
#                 }
#             }
#         ]
#     },
#     {
#         "id": 48,
#         "short_name": "BIS",
#         "name": "Bureau of Industry and Security, Department of Commerce",
#         "parent_id": 45,
#         "cfr_references": [
#             {
#                 "id": 71,
#                 "agency_id": 48,
#                 "parent_agency_id": 45,
#                 "reference": {
#                     "title": 15,
#                     "chapter": "VII"
#                 }
#             }
#         ]
#     },
#     {
#         "id": 49,
#         "short_name": "EDA",
#         "name": "Economic Development Administration, Department of Commerce",
#         "parent_id": 45,
#         "cfr_references": [
#             {
#                 "id": 72,
#                 "agency_id": 49,
#                 "parent_agency_id": 45,
#                 "reference": {
#                     "title": 13,
#                     "chapter": "III"
#                 }
#             }
#         ]
#     },
#     {
#         "id": 50,
#         "short_name": "FTZB",
#         "name": "Foreign-Trade Zones Board, Department of Commerce",
#         "parent_id": 45,
#         "cfr_references": [
#             {
#                 "id": 73,
#                 "agency_id": 50,
#                 "parent_agency_id": 45,
#                 "reference": {
#                     "title": 15,
#                     "chapter": "IV"
#                 }
#             }
#         ]
#     },
#     {
#         "id": 51,
#         "short_name": "ITA",
#         "name": "International Trade Administration, Department of Commerce",
#         "parent_id": 45,
#         "cfr_references": [
#             {
#                 "id": 74,
#                 "agency_id": 51,
#                 "parent_agency_id": 45,
#                 "reference": {
#                     "title": 15,
#                     "chapter": "III"
#                 }
#             },
#             {
#                 "id": 75,
#                 "agency_id": 51,
#                 "parent_agency_id": 45,
#                 "reference": {
#                     "title": 19,
#                     "chapter": "III"
#                 }
#             }
#         ]
#     },
#     {
#         "id": 52,
#         "short_name": "MBDA",
#         "name": "Minority Business Development Agency, Department of Commerce",
#         "parent_id": 45,
#         "cfr_references": [
#             {
#                 "id": 76,
#                 "agency_id": 52,
#                 "parent_agency_id": 45,
#                 "reference": {
#                     "title": 15,
#                     "chapter": "XIV"
#                 }
#             }
#         ]
#     },
#     {
#         "id": 53,
#         "short_name": "NIST",
#         "name": "National Institute of Standards and Technology, Department of Commerce",
#         "parent_id": 45,
#         "cfr_references": [
#             {
#                 "id": 77,
#                 "agency_id": 53,
#                 "parent_agency_id": 45,
#                 "reference": {
#                     "title": 15,
#                     "chapter": "II"
#                 }
#             },
#             {
#                 "id": 78,
#                 "agency_id": 53,
#                 "parent_agency_id": 45,
#                 "reference": {
#                     "title": 37,
#                     "chapter": "IV"
#                 }
#             }
#         ]
#     },
#     {
#         "id": 54,
#         "short_name": "NOAA",
#         "name": "National Oceanic and Atmospheric Administration, Department of Commerce",
#         "parent_id": 45,
#         "cfr_references": [
#             {
#                 "id": 79,
#                 "agency_id": 54,
#                 "parent_agency_id": 45,
#                 "reference": {
#                     "title": 15,
#                     "chapter": "IX"
#                 }
#             },
#             {
#                 "id": 80,
#                 "agency_id": 54,
#                 "parent_agency_id": 45,
#                 "reference": {
#                     "title": 50,
#                     "chapter": "III"
#                 }
#             },
#             {
#                 "id": 81,
#                 "agency_id": 54,
#                 "parent_agency_id": 45,
#                 "reference": {
#                     "title": 50,
#                     "chapter": "IV"
#                 }
#             }
#         ]
#     },
#     {
#         "id": 55,
#         "short_name": "",
#         "name": "National Oceanic and Atmospheric Administration National Marine Fisheries Service, Department of Commerce",
#         "parent_id": 45,
#         "cfr_references": [
#             {
#                 "id": 82,
#                 "agency_id": 55,
#                 "parent_agency_id": 45,
#                 "reference": {
#                     "title": 50,
#                     "chapter": "II"
#                 }
#             }
#         ]
#     },
#     {
#         "id": 56,
#         "short_name": "NTIS",
#         "name": "National Technical Information Service, Department of Commerce",
#         "parent_id": 45,
#         "cfr_references": [
#             {
#                 "id": 83,
#                 "agency_id": 56,
#                 "parent_agency_id": 45,
#                 "reference": {
#                     "title": 15,
#                     "chapter": "XI"
#                 }
#             }
#         ]
#     },
#     {
#         "id": 57,
#         "short_name": "NTIA",
#         "name": "National Telecommunications and Information Administration, Department of Commerce",
#         "parent_id": 45,
#         "cfr_references": [
#             {
#                 "id": 84,
#                 "agency_id": 57,
#                 "parent_agency_id": 45,
#                 "reference": {
#                     "title": 15,
#                     "chapter": "XXIII"
#                 }
#             },
#             {
#                 "id": 85,
#                 "agency_id": 57,
#                 "parent_agency_id": 45,
#                 "reference": {
#                     "title": 47,
#                     "chapter": "III"
#                 }
#             },
#             {
#                 "id": 86,
#                 "agency_id": 57,
#                 "parent_agency_id": 45,
#                 "reference": {
#                     "title": 47,
#                     "chapter": "IV"
#                 }
#             }
#         ]
#     },
#     {
#         "id": 58,
#         "short_name": "",
#         "name": "Office of Secretary of Commerce, Department of Commerce",
#         "parent_id": 45,
#         "cfr_references": [
#             {
#                 "id": 87,
#                 "agency_id": 58,
#                 "parent_agency_id": 45,
#                 "reference": {
#                     "title": 15,
#                     "subtitle": "A"
#                 }
#             }
#         ]
#     },
#     {
#         "id": 59,
#         "short_name": "OUSEA",
#         "name": "Office of Under-Secretary for Economic Affairs, Department of Commerce",
#         "parent_id": 45,
#         "cfr_references": [
#             {
#                 "id": 88,
#                 "agency_id": 59,
#                 "parent_agency_id": 45,
#                 "reference": {
#                     "title": 15,
#                     "chapter": "XV"
#                 }
#             }
#         ]
#     },
#     {
#         "id": 60,
#         "short_name": "PTO",
#         "name": "United States Patent and Trademark Office, Department of Commerce",
#         "parent_id": 45,
#         "cfr_references": [
#             {
#                 "id": 89,
#                 "agency_id": 60,
#                 "parent_agency_id": 45,
#                 "reference": {
#                     "title": 37,
#                     "chapter": "I"
#                 }
#             }
#         ]
#     },
#     {
#         "id": 61,
#         "short_name": "CFTC",
#         "name": "Commodity Futures Trading Commission",
#         "parent_id": null,
#         "cfr_references": [
#             {
#                 "id": 90,
#                 "agency_id": 61,
#                 "parent_agency_id": null,
#                 "reference": {
#                     "title": 5,
#                     "chapter": "XLI"
#                 }
#             },
#             {
#                 "id": 91,
#                 "agency_id": 61,
#                 "parent_agency_id": null,
#                 "reference": {
#                     "title": 17,
#                     "chapter": "I"
#                 }
#             }
#         ]
#     },
#     {
#         "id": 62,
#         "short_name": null,
#         "name": "Construction Industry Collective Bargaining Commission",
#         "parent_id": null,
#         "cfr_references": [
#             {
#                 "id": 92,
#                 "agency_id": 62,
#                 "parent_agency_id": null,
#                 "reference": {
#                     "title": 29,
#                     "chapter": "IX"
#                 }
#             }
#         ]
#     },
#     {
#         "id": 63,
#         "short_name": "CFPB",
#         "name": "Consumer Financial Protection Bureau",
#         "parent_id": null,
#         "cfr_references": [
#             {
#                 "id": 93,
#                 "agency_id": 63,
#                 "parent_agency_id": null,
#                 "reference": {
#                     "title": 5,
#                     "chapter": "LXXXIV"
#                 }
#             },
#             {
#                 "id": 94,
#                 "agency_id": 63,
#                 "parent_agency_id": null,
#                 "reference": {
#                     "title": 12,
#                     "chapter": "X"
#                 }
#             }
#         ]
#     },
#     {
#         "id": 64,
#         "short_name": "CPSC",
#         "name": "Consumer Product Safety Commission",
#         "parent_id": null,
#         "cfr_references": [
#             {
#                 "id": 95,
#                 "agency_id": 64,
#                 "parent_agency_id": null,
#                 "reference": {
#                     "title": 5,
#                     "chapter": "LXXI"
#                 }
#             },
#             {
#                 "id": 96,
#                 "agency_id": 64,
#                 "parent_agency_id": null,
#                 "reference": {
#                     "title": 16,
#                     "chapter": "II"
#                 }
#             }
#         ]
#     },
#     {
#         "id": 65,
#         "short_name": "CIGIE",
#         "name": "Council of the Inspectors General on Integrity and Efficiency",
#         "parent_id": null,
#         "cfr_references": [
#             {
#                 "id": 97,
#                 "agency_id": 65,
#                 "parent_agency_id": null,
#                 "reference": {
#                     "title": 5,
#                     "chapter": "XCVIII"
#                 }
#             }
#         ]
#     },
#     {
#         "id": 66,
#         "short_name": "CSOSA",
#         "name": "Court Services and Offender Supervision Agency for the District of Columbia",
#         "parent_id": null,
#         "cfr_references": [
#             {
#                 "id": 98,
#                 "agency_id": 66,
#                 "parent_agency_id": null,
#                 "reference": {
#                     "title": 5,
#                     "chapter": "LXX"
#                 }
#             },
#             {
#                 "id": 99,
#                 "agency_id": 66,
#                 "parent_agency_id": null,
#                 "reference": {
#                     "title": 28,
#                     "chapter": "VIII"
#                 }
#             }
#         ]
#     },
#     {
#         "id": 67,
#         "short_name": "DNFSB",
#         "name": "Defense Nuclear Facilities Safety Board",
#         "parent_id": null,
#         "cfr_references": [
#             {
#                 "id": 100,
#                 "agency_id": 67,
#                 "parent_agency_id": null,
#                 "reference": {
#                     "title": 10,
#                     "chapter": "XVII"
#                 }
#             }
#         ]
#     },
#     {
#         "id": 68,
#         "short_name": "DOD",
#         "name": "Department of Defense",
#         "parent_id": null,
#         "cfr_references": [
#             {
#                 "id": 101,
#                 "agency_id": 68,
#                 "parent_agency_id": null,
#                 "reference": {
#                     "title": 2,
#                     "chapter": "XI"
#                 }
#             },
#             {
#                 "id": 102,
#                 "agency_id": 68,
#                 "parent_agency_id": null,
#                 "reference": {
#                     "title": 5,
#                     "chapter": "XXVI"
#                 }
#             },
#             {
#                 "id": 103,
#                 "agency_id": 68,
#                 "parent_agency_id": null,
#                 "reference": {
#                     "title": 32,
#                     "subtitle": "A"
#                 }
#             },
#             {
#                 "id": 104,
#                 "agency_id": 68,
#                 "parent_agency_id": null,
#                 "reference": {
#                     "title": 40,
#                     "chapter": "VII"
#                 }
#             }
#         ]
#     },
#     {
#         "id": 69,
#         "short_name": "COE",
#         "name": "Army Corps of Engineers, Department of Defense",
#         "parent_id": 68,
#         "cfr_references": [
#             {
#                 "id": 105,
#                 "agency_id": 69,
#                 "parent_agency_id": 68,
#                 "reference": {
#                     "title": 33,
#                     "chapter": "II"
#                 }
#             },
#             {
#                 "id": 106,
#                 "agency_id": 69,
#                 "parent_agency_id": 68,
#                 "reference": {
#                     "title": 36,
#                     "chapter": "III"
#                 }
#             }
#         ]
#     },
#     {
#         "id": 70,
#         "short_name": "DARS",
#         "name": "Defense Acquisition Regulations System, Department of Defense",
#         "parent_id": 68,
#         "cfr_references": [
#             {
#                 "id": 107,
#                 "agency_id": 70,
#                 "parent_agency_id": 68,
#                 "reference": {
#                     "title": 48,
#                     "chapter": "2"
#                 }
#             }
#         ]
#     },
#     {
#         "id": 71,
#         "short_name": "DLA",
#         "name": "Defense Logistics Agency, Department of Defense",
#         "parent_id": 68,
#         "cfr_references": [
#             {
#                 "id": 108,
#                 "agency_id": 71,
#                 "parent_agency_id": 68,
#                 "reference": {
#                     "title": 32,
#                     "chapter": "XII"
#                 }
#             },
#             {
#                 "id": 109,
#                 "agency_id": 71,
#                 "parent_agency_id": 68,
#                 "reference": {
#                     "title": 48,
#                     "chapter": "54"
#                 }
#             }
#         ]
#     },
#     {
#         "id": 72,
#         "short_name": "",
#         "name": "Department of Navy Acquisition Regulations, Department of Defense",
#         "parent_id": 68,
#         "cfr_references": [
#             {
#                 "id": 110,
#                 "agency_id": 72,
#                 "parent_agency_id": 68,
#                 "reference": {
#                     "title": 48,
#                     "chapter": "52"
#                 }
#             }
#         ]
#     },
#     {
#         "id": 74,
#         "short_name": "",
#         "name": "Office of the Secretary, Department of Defense",
#         "parent_id": 68,
#         "cfr_references": [
#             {
#                 "id": 111,
#                 "agency_id": 74,
#                 "parent_agency_id": 68,
#                 "reference": {
#                     "title": 32,
#                     "chapter": "I"
#                 }
#             }
#         ]
#     },
#     {
#         "id": 75,
#         "short_name": "DRBC",
#         "name": "Delaware River Basin Commission",
#         "parent_id": null,
#         "cfr_references": [
#             {
#                 "id": 112,
#                 "agency_id": 75,
#                 "parent_agency_id": null,
#                 "reference": {
#                     "title": 18,
#                     "chapter": "III"
#                 }
#             }
#         ]
#     },
#     {
#         "id": 76,
#         "short_name": "DC",
#         "name": "Denali Commission",
#         "parent_id": null,
#         "cfr_references": [
#             {
#                 "id": 113,
#                 "agency_id": 76,
#                 "parent_agency_id": null,
#                 "reference": {
#                     "title": 45,
#                     "chapter": "IX"
#                 }
#             }
#         ]
#     },
#     {
#         "id": 77,
#         "short_name": "ODNI",
#         "name": "Office of Director of National Intelligence",
#         "parent_id": null,
#         "cfr_references": [
#             {
#                 "id": 114,
#                 "agency_id": 77,
#                 "parent_agency_id": null,
#                 "reference": {
#                     "title": 5,
#                     "chapter": "IV"
#                 }
#             },
#             {
#                 "id": 115,
#                 "agency_id": 77,
#                 "parent_agency_id": null,
#                 "reference": {
#                     "title": 32,
#                     "chapter": "XVII"
#                 }
#             }
#         ]
#     },
#     {
#         "id": 78,
#         "short_name": "NCD",
#         "name": "National Council on Disability",
#         "parent_id": null,
#         "cfr_references": [
#             {
#                 "id": 116,
#                 "agency_id": 78,
#                 "parent_agency_id": null,
#                 "reference": {
#                     "title": 5,
#                     "chapter": "C"
#                 }
#             },
#             {
#                 "id": 117,
#                 "agency_id": 78,
#                 "parent_agency_id": null,
#                 "reference": {
#                     "title": 34,
#                     "chapter": "XII"
#                 }
#             }
#         ]
#     },
#     {
#         "id": 79,
#         "short_name": null,
#         "name": "East-West Foreign Trade Board",
#         "parent_id": null,
#         "cfr_references": [
#             {
#                 "id": 118,
#                 "agency_id": 79,
#                 "parent_agency_id": null,
#                 "reference": {
#                     "title": 15,
#                     "chapter": "XIII"
#                 }
#             }
#         ]
#     },
#     {
#         "id": 80,
#         "short_name": "ED",
#         "name": "Department of Education",
#         "parent_id": null,
#         "cfr_references": [
#             {
#                 "id": 119,
#                 "agency_id": 80,
#                 "parent_agency_id": null,
#                 "reference": {
#                     "title": 2,
#                     "chapter": "XXXIV"
#                 }
#             },
#             {
#                 "id": 120,
#                 "agency_id": 80,
#                 "parent_agency_id": null,
#                 "reference": {
#                     "title": 5,
#                     "chapter": "LIII"
#                 }
#             }
#         ]
#     },
#     {
#         "id": 81,
#         "short_name": "",
#         "name": "Department of Education Acquisition Regulation",
#         "parent_id": 80,
#         "cfr_references": [
#             {
#                 "id": 121,
#                 "agency_id": 81,
#                 "parent_agency_id": 80,
#                 "reference": {
#                     "title": 48,
#                     "chapter": "34"
#                 }
#             }
#         ]
#     },
#     {
#         "id": 82,
#         "short_name": "",
#         "name": "Office for Civil Rights, Department of Education",
#         "parent_id": 80,
#         "cfr_references": [
#             {
#                 "id": 122,
#                 "agency_id": 82,
#                 "parent_agency_id": 80,
#                 "reference": {
#                     "title": 34,
#                     "chapter": "I"
#                 }
#             }
#         ]
#     },
#     {
#         "id": 83,
#         "short_name": "",
#         "name": "Office of and Adult Education Technical Career, Department of Education",
#         "parent_id": 80,
#         "cfr_references": [
#             {
#                 "id": 123,
#                 "agency_id": 83,
#                 "parent_agency_id": 80,
#                 "reference": {
#                     "title": 34,
#                     "chapter": "IV"
#                 }
#             }
#         ]
#     },
#     {
#         "id": 84,
#         "short_name": "",
#         "name": "Office of Bilingual Education and Minority Languages Affairs, Department of Education",
#         "parent_id": 80,
#         "cfr_references": [
#             {
#                 "id": 124,
#                 "agency_id": 84,
#                 "parent_agency_id": 80,
#                 "reference": {
#                     "title": 34,
#                     "chapter": "V"
#                 }
#             }
#         ]
#     },
#     {
#         "id": 85,
#         "short_name": "",
#         "name": "Office of Elementary and Secondary Education, Department of Education",
#         "parent_id": 80,
#         "cfr_references": [
#             {
#                 "id": 125,
#                 "agency_id": 85,
#                 "parent_agency_id": 80,
#                 "reference": {
#                     "title": 34,
#                     "chapter": "II"
#                 }
#             }
#         ]
#     },
#     {
#         "id": 86,
#         "short_name": null,
#         "name": "Office of Postsecondary Education, Department of Education",
#         "parent_id": 80,
#         "cfr_references": [
#             {
#                 "id": 126,
#                 "agency_id": 86,
#                 "parent_agency_id": 80,
#                 "reference": {
#                     "title": 34,
#                     "chapter": "VI"
#                 }
#             }
#         ]
#     },
#     {
#         "id": 87,
#         "short_name": "",
#         "name": "Office of Secretary of Education, Department of Education",
#         "parent_id": 80,
#         "cfr_references": [
#             {
#                 "id": 127,
#                 "agency_id": 87,
#                 "parent_agency_id": 80,
#                 "reference": {
#                     "title": 34,
#                     "subtitle": "A"
# ...
#                 "reference": {
#                     "title": 23,
#                     "chapter": "I"
#                 }
#             },
#             {
#                 "id": 448,
#                 "agency_id": 287,
#                 "parent_agency_id": 284,
#                 "reference": {
#                     "title": 23,
#                     "chapter": "II"
#                 }
#             }
#         ]
#     },
#     {
#         "id": 288,
#         "short_name": "FMCSA",
#         "name": "Federal Motor Carrier Safety Administration, Department of Transportation",
#         "parent_id": 284,
#         "cfr_references": [
#             {
#                 "id": 449,
#                 "agency_id": 288,
#                 "parent_agency_id": 284,
#                 "reference": {
#                     "title": 49,
#                     "chapter": "III"
#                 }
#             }
#         ]
#     },
#     {
#         "id": 289,
#         "short_name": "FRA",
#         "name": "Federal Railroad Administration, Department of Transportation",
#         "parent_id": 284,
#         "cfr_references": [
#             {
#                 "id": 450,
#                 "agency_id": 289,
#                 "parent_agency_id": 284,
#                 "reference": {
#                     "title": 49,
#                     "chapter": "II"
#                 }
#             }
#         ]
#     },
#     {
#         "id": 290,
#         "short_name": "FTA",
#         "name": "Federal Transit Administration, Department of Transportation",
#         "parent_id": 284,
#         "cfr_references": [
#             {
#                 "id": 451,
#                 "agency_id": 290,
#                 "parent_agency_id": 284,
#                 "reference": {
#                     "title": 49,
#                     "chapter": "VI"
#                 }
#             }
#         ]
#     },
#     {
#         "id": 291,
#         "short_name": "SAINT",
#         "name": "Great Lakes St. Lawrence Seaway Development Corporation, Department of Transportation",
#         "parent_id": 284,
#         "cfr_references": [
#             {
#                 "id": 452,
#                 "agency_id": 291,
#                 "parent_agency_id": 284,
#                 "reference": {
#                     "title": 33,
#                     "chapter": "IV"
#                 }
#             }
#         ]
#     },
#     {
#         "id": 292,
#         "short_name": "MARAD",
#         "name": "Maritime Administration, Department of Transportation",
#         "parent_id": 284,
#         "cfr_references": [
#             {
#                 "id": 453,
#                 "agency_id": 292,
#                 "parent_agency_id": 284,
#                 "reference": {
#                     "title": 46,
#                     "chapter": "II"
#                 }
#             }
#         ]
#     },
#     {
#         "id": 293,
#         "short_name": "NHTSA",
#         "name": "National Highway Traffic Safety Administration, Department of Transportation",
#         "parent_id": 284,
#         "cfr_references": [
#             {
#                 "id": 454,
#                 "agency_id": 293,
#                 "parent_agency_id": 284,
#                 "reference": {
#                     "title": 23,
#                     "chapter": "II"
#                 }
#             },
#             {
#                 "id": 455,
#                 "agency_id": 293,
#                 "parent_agency_id": 284,
#                 "reference": {
#                     "title": 23,
#                     "chapter": "III"
#                 }
#             },
#             {
#                 "id": 456,
#                 "agency_id": 293,
#                 "parent_agency_id": 284,
#                 "reference": {
#                     "title": 47,
#                     "chapter": "IV"
#                 }
#             },
#             {
#                 "id": 457,
#                 "agency_id": 293,
#                 "parent_agency_id": 284,
#                 "reference": {
#                     "title": 49,
#                     "chapter": "V"
#                 }
#             }
#         ]
#     },
#     {
#         "id": 294,
#         "short_name": null,
#         "name": "Office of Secretary (Aviation Proceedings), Department of Transportation",
#         "parent_id": 284,
#         "cfr_references": [
#             {
#                 "id": 458,
#                 "agency_id": 294,
#                 "parent_agency_id": 284,
#                 "reference": {
#                     "title": 14,
#                     "chapter": "II"
#                 }
#             }
#         ]
#     },
#     {
#         "id": 295,
#         "short_name": "",
#         "name": "Office of Secretary of Transportation, Department of Transportation",
#         "parent_id": 284,
#         "cfr_references": [
#             {
#                 "id": 459,
#                 "agency_id": 295,
#                 "parent_agency_id": 284,
#                 "reference": {
#                     "title": 49,
#                     "subtitle": "A"
#                 }
#             }
#         ]
#     },
#     {
#         "id": 296,
#         "short_name": "PHMSA",
#         "name": "Pipeline and Hazardous Materials Safety Administration, Department of Transportation",
#         "parent_id": 284,
#         "cfr_references": [
#             {
#                 "id": 460,
#                 "agency_id": 296,
#                 "parent_agency_id": 284,
#                 "reference": {
#                     "title": 49,
#                     "chapter": "I"
#                 }
#             }
#         ]
#     },
#     {
#         "id": 297,
#         "short_name": "TREAS",
#         "name": "Department of Treasury",
#         "parent_id": null,
#         "cfr_references": [
#             {
#                 "id": 461,
#                 "agency_id": 297,
#                 "parent_agency_id": null,
#                 "reference": {
#                     "title": 2,
#                     "chapter": "X"
#                 }
#             },
#             {
#                 "id": 462,
#                 "agency_id": 297,
#                 "parent_agency_id": null,
#                 "reference": {
#                     "title": 5,
#                     "chapter": "XXI"
#                 }
#             },
#             {
#                 "id": 463,
#                 "agency_id": 297,
#                 "parent_agency_id": null,
#                 "reference": {
#                     "title": 12,
#                     "chapter": "XV"
#                 }
#             },
#             {
#                 "id": 464,
#                 "agency_id": 297,
#                 "parent_agency_id": null,
#                 "reference": {
#                     "title": 17,
#                     "chapter": "IV"
#                 }
#             },
#             {
#                 "id": 465,
#                 "agency_id": 297,
#                 "parent_agency_id": null,
#                 "reference": {
#                     "title": 31,
#                     "chapter": "IX"
#                 }
#             },
#             {
#                 "id": 466,
#                 "agency_id": 297,
#                 "parent_agency_id": null,
#                 "reference": {
#                     "title": 48,
#                     "chapter": "10"
#                 }
#             }
#         ]
#     },
#     {
#         "id": 298,
#         "short_name": "TTB",
#         "name": "Alcohol and Tobacco Tax and Trade Bureau, Department of Treasury",
#         "parent_id": 297,
#         "cfr_references": [
#             {
#                 "id": 467,
#                 "agency_id": 298,
#                 "parent_agency_id": 297,
#                 "reference": {
#                     "title": 27,
#                     "chapter": "I"
#                 }
#             }
#         ]
#     },
#     {
#         "id": 299,
#         "short_name": "BEP",
#         "name": "Bureau of Engraving and Printing, Department of Treasury",
#         "parent_id": 297,
#         "cfr_references": [
#             {
#                 "id": 468,
#                 "agency_id": 299,
#                 "parent_agency_id": 297,
#                 "reference": {
#                     "title": 31,
#                     "chapter": "VI"
#                 }
#             }
#         ]
#     },
#     {
#         "id": 300,
#         "short_name": "",
#         "name": "Bureau of the Fiscal Service, Department of Treasury",
#         "parent_id": 297,
#         "cfr_references": [
#             {
#                 "id": 469,
#                 "agency_id": 300,
#                 "parent_agency_id": 297,
#                 "reference": {
#                     "title": 31,
#                     "chapter": "II",
#                     "subchapter": "A"
#                 }
#             }
#         ]
#     },
#     {
#         "id": 301,
#         "short_name": "CDFI",
#         "name": "Community Development Financial Institutions Fund, Department of Treasury",
#         "parent_id": 297,
#         "cfr_references": [
#             {
#                 "id": 470,
#                 "agency_id": 301,
#                 "parent_agency_id": 297,
#                 "reference": {
#                     "title": 12,
#                     "chapter": "XVIII"
#                 }
#             }
#         ]
#     },
#     {
#         "id": 302,
#         "short_name": "OCC",
#         "name": "Comptroller of the Currency, Department of Treasury",
#         "parent_id": 297,
#         "cfr_references": [
#             {
#                 "id": 471,
#                 "agency_id": 302,
#                 "parent_agency_id": 297,
#                 "reference": {
#                     "title": 12,
#                     "chapter": "I"
#                 }
#             }
#         ]
#     },
#     {
#         "id": 303,
#         "short_name": "TD",
#         "name": "Financial Crimes Enforcement Network, Department of Treasury",
#         "parent_id": 297,
#         "cfr_references": [
#             {
#                 "id": 472,
#                 "agency_id": 303,
#                 "parent_agency_id": 297,
#                 "reference": {
#                     "title": 31,
#                     "chapter": "X"
#                 }
#             }
#         ]
#     },
#     {
#         "id": 304,
#         "short_name": "FS",
#         "name": "Fiscal Service, Department of Treasury",
#         "parent_id": 297,
#         "cfr_references": [
#             {
#                 "id": 473,
#                 "agency_id": 304,
#                 "parent_agency_id": 297,
#                 "reference": {
#                     "title": 31,
#                     "chapter": "II"
#                 }
#             }
#         ]
#     },
#     {
#         "id": 305,
#         "short_name": "IRS",
#         "name": "Internal Revenue Service, Department of Treasury",
#         "parent_id": 297,
#         "cfr_references": [
#             {
#                 "id": 474,
#                 "agency_id": 305,
#                 "parent_agency_id": 297,
#                 "reference": {
#                     "title": 26,
#                     "chapter": "I"
#                 }
#             }
#         ]
#     },
#     {
#         "id": 306,
#         "short_name": "",
#         "name": "Monetary Offices, Department of Treasury",
#         "parent_id": 297,
#         "cfr_references": [
#             {
#                 "id": 475,
#                 "agency_id": 306,
#                 "parent_agency_id": 297,
#                 "reference": {
#                     "title": 31,
#                     "chapter": "I"
#                 }
#             }
#         ]
#     },
#     {
#         "id": 307,
#         "short_name": "",
#         "name": "Office of Financial Research, Department of Treasury",
#         "parent_id": 297,
#         "cfr_references": [
#             {
#                 "id": 476,
#                 "agency_id": 307,
#                 "parent_agency_id": 297,
#                 "reference": {
#                     "title": 12,
#                     "chapter": "XVI"
#                 }
#             }
#         ]
#     },
#     {
#         "id": 308,
#         "short_name": "OFAC",
#         "name": "Office of Foreign Assets Control, Department of Treasury",
#         "parent_id": 297,
#         "cfr_references": [
#             {
#                 "id": 477,
#                 "agency_id": 308,
#                 "parent_agency_id": 297,
#                 "reference": {
#                     "title": 31,
#                     "chapter": "V"
#                 }
#             }
#         ]
#     },
#     {
#         "id": 309,
#         "short_name": "IIO",
#         "name": "Office of Investment Security, Department of Treasury",
#         "parent_id": 297,
#         "cfr_references": [
#             {
#                 "id": 478,
#                 "agency_id": 309,
#                 "parent_agency_id": 297,
#                 "reference": {
#                     "title": 31,
#                     "chapter": "VIII"
#                 }
#             }
#         ]
#     },
#     {
#         "id": 310,
#         "short_name": "",
#         "name": "Office of Secretary of the Treasury, Department of Treasury",
#         "parent_id": 297,
#         "cfr_references": [
#             {
#                 "id": 479,
#                 "agency_id": 310,
#                 "parent_agency_id": 297,
#                 "reference": {
#                     "title": 31,
#                     "subtitle": "A"
#                 }
#             }
#         ]
#     },
#     {
#         "id": 311,
#         "short_name": "USTR",
#         "name": "Office of United States Trade Representative",
#         "parent_id": null,
#         "cfr_references": [
#             {
#                 "id": 480,
#                 "agency_id": 311,
#                 "parent_agency_id": null,
#                 "reference": {
#                     "title": 15,
#                     "chapter": "XX"
#                 }
#             }
#         ]
#     },
#     {
#         "id": 312,
#         "short_name": "URMCC",
#         "name": "Utah Reclamation Mitigation and Conservation Commission",
#         "parent_id": null,
#         "cfr_references": [
#             {
#                 "id": 481,
#                 "agency_id": 312,
#                 "parent_agency_id": null,
#                 "reference": {
#                     "title": 43,
#                     "chapter": "III"
#                 }
#             }
#         ]
#     },
#     {
#         "id": 313,
#         "short_name": "VA",
#         "name": "Department of Veterans Affairs",
#         "parent_id": null,
#         "cfr_references": [
#             {
#                 "id": 482,
#                 "agency_id": 313,
#                 "parent_agency_id": null,
#                 "reference": {
#                     "title": 2,
#                     "chapter": "VIII"
#                 }
#             },
#             {
#                 "id": 483,
#                 "agency_id": 313,
#                 "parent_agency_id": null,
#                 "reference": {
#                     "title": 38,
#                     "chapter": "I"
#                 }
#             },
#             {
#                 "id": 484,
#                 "agency_id": 313,
#                 "parent_agency_id": null,
#                 "reference": {
#                     "title": 48,
#                     "chapter": "8"
#                 }
#             }
#         ]
#     },
#     {
#         "id": 314,
#         "short_name": null,
#         "name": "Office of Vice President of the United States",
#         "parent_id": null,
#         "cfr_references": [
#             {
#                 "id": 485,
#                 "agency_id": 314,
#                 "parent_agency_id": null,
#                 "reference": {
#                     "title": 32,
#                     "chapter": "XXVIII"
#                 }
#             }
#         ]
#     },
#     {
#         "id": 315,
#         "short_name": null,
#         "name": "Water Resources Council",
#         "parent_id": null,
#         "cfr_references": [
#             {
#                 "id": 486,
#                 "agency_id": 315,
#                 "parent_agency_id": null,
#                 "reference": {
#                     "title": 18,
#                     "chapter": "VI"
#                 }
#             }
#         ]
#     },
#     {
#         "id": 316,
#         "short_name": "",
#         "name": "President's Commission on White House Fellowships",
#         "parent_id": null,
#         "cfr_references": [
#             {
#                 "id": 487,
#                 "agency_id": 316,
#                 "parent_agency_id": null,
#                 "reference": {
#                     "part": "425",
#                     "title": 1,
#                     "chapter": "IV"
#                 }
#             }
#         ]
#     }
# ]
